# %% [markdown]
# <a href="https://colab.research.google.com/github/osvaldomaguey/Andes-Retail-Group-Desempeno-Comercial/blob/main/Andes_Retail_Desempeno_Comercial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📊 Proyecto: Dashboard de desempeño comercial 2024–2025
# Empresa: **Andes Retail Group**
#
# Este notebook servirá como guía estructurada para el desarrollo del proyecto en Power BI.

# %% [markdown]
# ## 🔹 Paso 1: Conexión y Exploración
#
# - Importa el archivo excel en Power BI Desktop.
# - Revisa tipos de datos.
# - Identifica columnas clave.
# - Explora estructura general del dataset.

# %% [markdown]
# ## 🔹 Paso 2: Transformación con Power Query
#
# - Cambia el formato de `Fecha_pedido` a español (Latinoamérica).
# - Corrige los **tipos de datos** de columnas numéricas.
# - Crea una columna condicional `Nivel_Venta` basada en `Ingresos`. Reglas:
#   - Si `Ingresos` es mayor o igual a 1000 → "Venta Alta"
#   - De lo contrario → "Venta Baja"
# - Activa **Vista Perfil de Columna** para validar calidad.
# - Deja el dataset listo para análisis.

# %% [markdown]
# ## 🔹 Paso 3: Diseño y planificación del Dashboard (antes y durante la construcción)
#
# - Define qué pregunta responde cada vista (Overview y Detalle).
# - Especifica qué KPIs incluirás y por qué.
# - Explica qué gráfico usarás para cada pregunta y justifica la elección.
# - Describe la jerarquía visual (qué verá primero el usuario).
#     - Indica cómo distribuirás los elementos en la página.
# - Especifica qué segmentadores usaras

# %% [markdown]
# ### Diseño y planificación
# ✏️ Describe aquí brevemente tu planificación antes de construir el dashboard.
# - Haz una planeación inicial, después, conforme vayas creando el dashboard, puedes regresar y modificar estas secciones acorde a lo que vayas encontrando.
#
# #### Vista Overview - ¿Cómo ha evolucionado el ingreso total entre 2024 y 2025?
# Especifica qué KPIs incluirás y por qué: (3-4 KPIs)
# - Ingresos: Para ver el total de los ingresos
# - Costo: Para ver el costo total
# - Margen: Permite al stakeholder ver la rentabilidad
# - No. de pedidos: Para ver la cantidad de pedidos por año
# - No. de clientes: Para ver la cantidad de coientes totales por año
#
# Explica qué gráfico usarás para cada pregunta y justifica la elección.
# - Gráfico de tiempo: Grafico de línea ya que es una variable numerica con una de fecha.
# - Gráfico comparación geográfica y categoria de producto: Barras que muestran claramente en que pais predomina que categoria de producto
# - Gráfico comparación clientes:Barras apiladas que permiten ver el ingreso y la rentabilidad por tipo de cliente.
#
# Descripción de la jerarquía visual:
#
# **Nivel 1**
# - Título: Performance comercial 2024-2025. Escogí este título, por que me parece que deja en claro el propósito del dashboard -> Que tan bien le fue al negocio en términos de rentabilidad en los años 2024 y 2025
# - 5 KPIs relevantes al desempeño económico
#
# **Nivel 2**
# - Graficos de barras y temporales: Con títulos y subtítulos cortos y claros para guiar al lector hacia la conclusión obvia
# - Se utilzaron colores para diferenciar los ingresos por país y asi facilitarbla lectura.
#
# **Nivel 3**
# - Segmentador de año, para hacer un filtrado rápido para la comparación por años
#
# #### Vista detalle - ¿Por qué se han caido/subido/mantenido los ingresos?
# Explica qué gráfico usarás para cada pregunta y justifica la elección.
# - Gráfico comparación estacional contra ingresos: Gráfico de barras apiladas - `Ingresos` vs `Segmento_Cliente` y `Estación`
# - Gráfico comparación nivel de vebnta e ingresos contra contra tipo de cliente : Gráfico de barras apiladas - `Ingresos` y `Nivel_Venta` vs `Segmento_cliente` y `Estación`
#
# - Tabla mostrando 4-6 columnas:
#   - Conteo único `ID_Cliente`
#   - Origen del cliente `Pais`
#   - Suma Ingresos `Ingresos`
#   - Que tipo de cliente compró `Segmento_Cliente`
#   - ¿Qué compró? `Categoria_producto`
#   - En que epoca del año compro `Estación`
#   - Fecha de la compra `Fecha` (Año y quarter)
#   - Que tipo de vebta fue `Nivel_Venta`
#
# Segmentadores (mínimo 2)
# - `Categoría de producto`
# - `País`

# %% [markdown]
# ## 🔹 Paso 4: Crear visualizaciones efectivas
#
# - Construir Vista 1 (Overview Ejecutivo).
# - Construir Vista 2 (Análisis Detallado).
# - Asegurar claridad y coherencia visual.

# %% [markdown]
# ## 🔹 Paso 5: Narrativa con Modelo SCQA + mensaje asincrónico
#
# - Escribe la narrativa que
#   - refleja lo que se observa en la **Vista General (Overview)**.
#   - explica los hallazgos en la **Vista Detalle**.
# - Utiliza el modelo **SCQA (Situación, Complicación, Pregunta, Respuesta)**.
# - Mantén la narrativa clara, ejecutiva y breve.
# - Redacta un mensaje ejecutivo tipo Slack resumiendo el insight principal.

# %% [markdown]
# ### Narrativa del Dashboard (Modelo SCQA)
# Se describe de forma estructurada la historia completa del dashboard usando SCQA, incluyendo contexto, problemas detectados, preguntas de negocio y recomendaciones basadas en datos.

# %% [markdown]
# #### 🖥️ Vista General (Overview)
#
# **S (Situación):**
# Andes Retail Group presenta un patrón de ventas claramente estacional, con picos en verano (diciembre-enero) y caídas pronunciadas en invierno (junio-agosto), donde las ventas están consistentemente por debajo de la media anual.
#
# **C (Complicación):**
# Sin embargo, además de la estacionalidad esperada, se observa una disminución general de ingresos de 2024 a 2025, lo que genera incertidumbre sobre si se trata únicamente de un patrón estacional natural o si existe una fricción en el embudo de ventas que está afectando el rendimiento del negocio.
#
# **Q (Pregunta):**
# La caída de ingresos se debe exclusivamente a factores estacionales predecibles, o existen problemas estructurales en el embudo de ventas que requieren intervención estratégica?
#
# **A (Respuesta):**
# El análisis del dashboard revela que ambos factores están presentes: existe un patrón estacional claro pero también una tendencia decreciente año a año que sugiere oportunidades de optimización, especialmente en los segmentos económicos y durante los meses de menor actividad.
#
# #### 🔎 Vista Detalle
#
# **S (Situación):**
# El análisis detallado de Andes Retail Group revela que los tres segmentos de clientes (Económico, Estándar y Premium) presentan patrones de comportamiento diferenciados a lo largo del año, con variaciones significativas tanto en volumen como en valor de compra.
#
# **C (Complicación):**
# Sin embargo, existe una inversión preocupante en el comportamiento de compra: mientras que en verano dominan las ventas altas (≥$1,000), durante otoño, primavera e invierno aumentan proporcionalmente las ventas bajas (<$1,000), lo que sugiere que los clientes no solo compran menos frecuentemente, sino que también reducen significativamente el valor de sus transacciones en temporadas frías.
#
# **Q (Pregunta):**
# ¿Qué segmentos de clientes y qué estrategias de valor de transacción representan las mayores oportunidades para mitigar la caída estacional y optimizar el mix de ventas altas vs bajas?
#
# **A (Respuesta):**
# El análisis granular muestra que la oportunidad está en dos frentes: (1) Activar el segmento Económico durante todo el año, ya que presenta el mayor potencial de crecimiento, y (2) Desarrollar estrategias específicas para mantener ventas altas durante otoño, primavera e invierno, enfocándose en los segmentos Premium y Estándar que históricamente generan mayor valor por transacción.

# %% [markdown]
# ### Mensaje asincrónico para Slack (Modelo SCQA)
#
# Resume los insights más importantes en un mensaje breve.
# - Comunica impacto en negocio y acciones recomendadas, como si lo enviaras a stakeholders por Slack.
# - Escribe un mensaje directo y conciso.

# %% [markdown]
# **📊 Actualización desempeño comercial**
#
# Equipo, se identificó una doble problemática:
# 1) **Estacionalidad esperada**: Picos en verano (dic-ene) y caídas en invierno (jun-ago)
# 2) **Tendencia decreciente**: Disminución general de ingresos de 2024 a 2025.
#
# Analizando los datos se descubrieron los siguientes hallazgos por segmento de cliente:
# - **Premium y Estándar**: Aportan mayor valor, y comportamiento similar en las diferentes épocas del año.
# - **Económico**: Segmento con mayor potencial sin explotar.
#
# Patrón crítico identificado:
# - **Verano**: Dominan ventas altas (≥$1,000)
#
# - **Resto del año**: Aumentan ventas bajas (<$1,000)
#
# Basado en estos insights, recomiendo:
#
# • Activar segmento Económico durante todo el año
#
# • Estrategias específicas para mantener ventas altas en temporadas frías
#
# • Enfoque en Electrónica y Deportes (categorías líderes)

# %% [markdown]
# ## 🚀 Entrega Final
#
# Comparte el acceso a tu proyecto final para revisión.
#
# Incluye **uno** de los siguientes:
# - 🔗 Link público del dashboard publicado (Power BI Service), o
# - 🔗 Link público de Google Drive/OneDrive con el archivo `.pbix`, o
# - ✅ Confirmación de que el archivo `.pbix` fue subido como indica el screencast.
#
# ### 📎 Enlace del proyecto:

# %%
https://drive.google.com/file/d/1i-Hr14IgE7y6L0g7VqvhHPqIZPtySV9t/view?usp=drivesdk
# Out:
#   Cell In[1], line 1
#     https://drive.google.com/file/d/1i-Hr14IgE7y6L0g7VqvhHPqIZPtySV9t/view?usp=drivesdk
#           ^
# SyntaxError: invalid syntax
